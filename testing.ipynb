# %%
2+3
# Out:
# 5

# %% [markdown]
# # Week 1 Tutorial
# ## learn jupyter lab
# Markdown stuff

# %%
print('what is going on dude')
# Out:
# what is going on dude

# %%
cd
# Out:
# C:\Users\Philip

# %%
dir
# Out:
# <function dir>

# %%
print("I am losing my damn mind trying to figure all this stuff out lmao")
# Out:
# I am losing my damn mind trying to figure all this stuff out lmao
